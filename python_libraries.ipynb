# %%
Numpy:

NumPy (Numerical Python) is a Python library used for numerical computing.
It provides support for arrays, matrices, and mathematical operations.
NumPy performs calculations faster than normal Python lists.


Important NumPy Functions

   Function         uses                               Example             
 
  np.array()      Creates a NumPy array               np.array([1,2,3])    
  np.zeros()      Creates an array of zeros           np.zeros(3)          
  np.ones()       Creates an array of ones            np.ones(3)           
  np.arange()     Creates a sequence of numbers       np.arange(1,6)       
  np.linspace()   Creates evenly spaced values        np.linspace(1,10,5)  
  np.reshape()    Changes the shape of an array       na.reshape(2,2)      
  np.sum()        Returns the sum of array elements   np.sum(a)            
  np.mean()       Returns the average value           np.mean(a)           
  np.max()        Returns the maximum value           np.max(a)            
  np.min()        Returns the minimum value           np.min(a)            
  np.sqrt()       Returns the square root             np.sqrt(25)          
  np.sort()       Sorts the array                     np.sort(a)           


_______________________________________________________________________________________________________________________________________________________________________________________________

    
pandas:
Definition

Pandas is an open-source Python library used for data analysis and data manipulation
It helps to read, clean, organize, filter, analyze, and visualize data efficiently.
Pandas mainly works with two data structures:



Pandas Functions, Uses, and Examples
 
   Function          Use                                                                     Example                                      

  read_csv()       Reads data from a CSV file                                                 df = pd.read_csv("student.csv")             
  head()           Displays the first 5 rows                                                  df.head()                                   
  tail()           Displays the last 5 rows                                                   df.tail()                                   
  info()           Shows information about the DataFrame (columns, data types, null values)   df.info()                                   
  describe()       Gives statistical summary of numerical data                                df.describe()                               
  shape            Returns the number of rows and columns                                     df.shape                                   
  columns          Displays all column names                                                  df.columns                                  
  drop()           Removes rows or columns                                                    df.drop("Age", axis=1)                      
  rename()         Renames columns                                                            df.rename(columns={"Name":"Student_Name"})  
  sort_values()    Sorts data based on a column                                               df.sort_values("Marks")                     
  fillna()         Replaces missing (NaN) values                                              df.fillna(0)                                
  isnull()         Checks for missing values                                                  df.isnull()                                 
  groupby()        Groups data based on a column                                              df.groupby("Department").sum()              
  value_counts()   Counts unique values in a column                                           df["Gender"].value_counts()                 
  to_csv()         Saves the DataFrame to a CSV file                                          df.to_csv("output.csv")                     

_______________________________________________________________________________________________________________________________________________________________________________________



seaborn:

What is Seaborn?

Seaborn is a Python data visualization library built on top of Matplotlib.
It is used to create attractive, informative, and statistical graphs with less code. It works especially well with Pandas DataFrames.

Seaborn Functions with Uses and Examples

       Seaborn Function     Simple Use                                        Example                                                  

   1  sns.scatterplot() | Shows the relationship between two variables.    | sns.scatterplot(x='Age', y='Salary', data=df)`            |
   2  sns.lineplot()    | Draws a line graph.                              | sns.lineplot(x='Month', y='Sales', data=df)`              |
   3  sns.barplot()     | Draws a bar chart.                               | sns.barplot(x='Department', y='Salary', data=df)`         |
   4  sns.countplot()   | Counts the number of items in each category.     | sns.countplot(x='Gender', data=df)`                       |
   5  sns.histplot()    | Shows the data distribution.                     | sns.histplot(x='Marks', data=df)`                         |
   6  sns.kdeplot()     | Shows the data density.                          | sns.kdeplot(x='Salary', data=df)`                         |
   7  sns.boxplot()     | Shows data spread and outliers.                  | sns.boxplot(x='Gender', y='Salary', data=df)`             |
   8  sns.violinplot()  | Shows the shape of the data distribution.        | sns.violinplot(x='Gender', y='Salary', data=df)`          |
   9  sns.stripplot()   | Shows individual data points.                    | sns.stripplot(x='Gender', y='Salary', data=df)`           |
  10  sns.swarmplot()   | Shows data points without overlap.               | sns.swarmplot(x='Gender', y='Salary', data=df)`           |
  11  sns.pairplot()    | Shows relationships between all numeric columns. | sns.pairplot(df)`                                         |
  12  sns.heatmap()     | Shows values using colors.                       | sns.heatmap(df.corr(), annot=True)`                       |
  13  sns.regplot()     | Shows a scatter plot with a trend line.          | sns.regplot(x='Age', y='Salary', data=df)`                |
  14  sns.jointplot()   | Shows the relationship between two variables.    | sns.jointplot(x='Age', y='Salary', data=df)`              |
  15  sns.catplot(`     | Creates different types of categorical plots.    | sns.catplot(x='Gender', y='Salary', kind='box', data=df)` |

_________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________



matplotlib:

Matplotlibis a popular Python library used for data visualization
It helps you create different types of graphs and charts such as line charts, bar charts, pie charts, histograms, scatter plots, and more.


   Function         Use                             Example                        

  plt.plot()      Draws a line graph               plt.plot(x, y)                  
  plt.scatter()   Creates a scatter plot           plt.scatter(x, y)               
  plt.bar()       Creates a vertical bar chart     plt.bar(x, y)                   
  plt.barh()      Creates a horizontal bar chart   plt.barh(x, y)                  
  plt.hist()      Creates a histogram              plt.hist(data)                  
  plt.pie()       Creates a pie chart              plt.pie(values, labels=labels)  
  plt.title()     Adds a title to the graph        plt.title("Sales Report")       
  plt.xlabel()    Labels the X-axis                plt.xlabel("Months")            
  plt.ylabel()    Labels the Y-axis                plt.ylabel("Sales")             
  plt.legend()    Displays the legend              plt.legend()                    
  plt.grid()      Adds grid lines                  plt.grid(True)                  
  plt.xlim()      Sets X-axis range                plt.xlim(0,10)                  
  plt.ylim()      Sets Y-axis range                plt.ylim(0,100)                 
  plt.savefig()   Saves the graph as an image      plt.savefig("graph.png")        
  plt.show()      Displays the graph               plt.show()
